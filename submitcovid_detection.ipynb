# %%
from IPython import display
import os
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as python_random
import tensorflow as tf
import seaborn as sns
import math
from sklearn.metrics import classification_report, confusion_matrix,plot_confusion_matrix
#from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
#test

np.random.seed(42)
tf.random.set_seed(42)

# %%
#Mounting Drive and dataset extraction 

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import the libraries
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/AI Covid detection/coviddataset.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/content') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
# ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from PIL import ImageFilter

height, width = 224, 224
batch_size=64


def generate_data(DIR):
    datagen = ImageDataGenerator(rescale=1./255.)
    
    generator = datagen.flow_from_directory(
        DIR,
        batch_size=batch_size,
        shuffle=True,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

TRAINING_DIR = '/content/Covid19-dataset/train'
TESTING_DIR = '/content/Covid19-dataset/test'

train_generator = generate_data(TRAINING_DIR)
test_generator = generate_data(TESTING_DIR)

total_image = np.concatenate([train_generator.labels,test_generator.labels])

print('\n\n',{'Normal_cases':len(np.where(total_image==0)[0]),
      'Viral_Pneumonia_cases':len(np.where(total_image==1)[0]),
             'Covid_cases':len(np.where(total_image==2)[0])})
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
#
#
#  {'Normal_cases': 90, 'Viral_Pneumonia_cases': 90, 'Covid_cases': 137}

# %% [markdown]
# <h3>Images demonstration<h3>

# %%
def image_plot(generator,image_numbers):
    img_feature = generator[0][0][:image_numbers]
    img_label = generator[0][1][:image_numbers]

    plt.figure(figsize=(20, 15))
    for i in range(image_numbers):
        ax = plt.subplot(math.ceil(image_numbers/4),4, i + 1)
        plt.imshow(img_feature[i])
        plt.title("Normal" if img_label[i] == 0 else "Viral Pneumonia" if img_label[i] == 1 else "Covid")
        plt.axis("off")

image_plot(train_generator,15)

# %%
from tensorflow.keras.layers.experimental import preprocessing

tf.keras.backend.clear_session()
input_shape = (height, width, 3)
base_model = tf.keras.applications.vgg16.VGG16(
    weights='imagenet', 
    include_top=False,
    input_shape=input_shape
)
base_model.trainable = False

model_vgg16 = tf.keras.Sequential()
model_vgg16.add(base_model)
model_vgg16.add(tf.keras.layers.GlobalAveragePooling2D())

model_vgg16.add(tf.keras.layers.Flatten())
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))

model_vgg16.add(tf.keras.layers.Dense(3, activation='softmax'))

model_vgg16.compile(loss='SparseCategoricalCrossentropy',
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['acc'])
model_vgg16.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 14,912,579
# Trainable params: 197,891
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=5)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        train_generator,
        validation_data = test_generator,
        #steps_per_epoch=10,
        epochs=50, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 4/4 [==============================] - ETA: 0s - loss: 1.3513 - acc: 0.3904
# Epoch 1: acc improved from -inf to 0.39044, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 32s 5s/step - loss: 1.3513 - acc: 0.3904 - val_loss: 1.0683 - val_acc: 0.3333
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0979 - acc: 0.4104
# Epoch 2: acc improved from 0.39044 to 0.41036, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 14s 3s/step - loss: 1.0979 - acc: 0.4104 - val_loss: 0.9931 - val_acc: 0.3939
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0891 - acc: 0.4582
# Epoch 3: acc improved from 0.41036 to 0.45817, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 14s 3s/step - loss: 1.0891 - acc: 0.4582 - val_loss: 0.9549 - val_acc: 0.3939
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9390 - acc: 0.5538
# Epoch 4: acc improved from 0.45817 to 0.55378, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.9390 - acc: 0.5538 - val_loss: 0.8540 - val_acc: 0.6970
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8914 - acc: 0.6135
# Epoch 5: acc improved from 0.55378 to 0.61355, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.8914 - acc: 0.6135 - val_loss: 0.7989 - val_acc: 0.7879
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8089 - acc: 0.6614
# Epoch 6: acc improved from 0.61355 to 0.66135, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.8089 - acc: 0.6614 - val_loss: 0.7065 - val_acc: 0.7727
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7524 - acc: 0.6653
# Epoch 7: acc improved from 0.66135 to 0.66534, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.7524 - acc: 0.6653 - val_loss: 0.6379 - val_acc: 0.7424
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6976 - acc: 0.6653
# Epoch 8: acc did not improve from 0.66534
# 4/4 [==============================] - 13s 3s/step - loss: 0.6976 - acc: 0.6653 - val_loss: 0.5863 - val_acc: 0.7424
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6343 - acc: 0.7610
# Epoch 9: acc improved from 0.66534 to 0.76096, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 12s 3s/step - loss: 0.6343 - acc: 0.7610 - val_loss: 0.5298 - val_acc: 0.8333
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 0.5424 - acc: 0.8287
# Epoch 10: acc improved from 0.76096 to 0.82869, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 4s/step - loss: 0.5424 - acc: 0.8287 - val_loss: 0.4782 - val_acc: 0.8788
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.5425 - acc: 0.8127
# Epoch 11: acc did not improve from 0.82869
# 4/4 [==============================] - 12s 3s/step - loss: 0.5425 - acc: 0.8127 - val_loss: 0.4460 - val_acc: 0.8788
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4761 - acc: 0.8367
# Epoch 12: acc improved from 0.82869 to 0.83665, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.4761 - acc: 0.8367 - val_loss: 0.4165 - val_acc: 0.8939
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4930 - acc: 0.7968
# Epoch 13: acc did not improve from 0.83665
# 4/4 [==============================] - 13s 3s/step - loss: 0.4930 - acc: 0.7968 - val_loss: 0.3884 - val_acc: 0.8636
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4480 - acc: 0.8486
# Epoch 14: acc improved from 0.83665 to 0.84861, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 12s 3s/step - loss: 0.4480 - acc: 0.8486 - val_loss: 0.3680 - val_acc: 0.8939
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4142 - acc: 0.8486
# Epoch 15: acc did not improve from 0.84861
# 4/4 [==============================] - 13s 3s/step - loss: 0.4142 - acc: 0.8486 - val_loss: 0.3478 - val_acc: 0.8636
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3766 - acc: 0.8486
# Epoch 16: acc did not improve from 0.84861
# 4/4 [==============================] - 13s 3s/step - loss: 0.3766 - acc: 0.8486 - val_loss: 0.3306 - val_acc: 0.8788
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3819 - acc: 0.8845
# Epoch 17: acc improved from 0.84861 to 0.88446, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.3819 - acc: 0.8845 - val_loss: 0.3125 - val_acc: 0.8788
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3466 - acc: 0.8725
# Epoch 18: acc did not improve from 0.88446
# 4/4 [==============================] - 13s 3s/step - loss: 0.3466 - acc: 0.8725 - val_loss: 0.3042 - val_acc: 0.8636
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3453 - acc: 0.8685
# Epoch 19: acc did not improve from 0.88446
# 4/4 [==============================] - 13s 3s/step - loss: 0.3453 - acc: 0.8685 - val_loss: 0.2826 - val_acc: 0.9394
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3151 - acc: 0.8685
# Epoch 20: acc did not improve from 0.88446
# 4/4 [==============================] - 12s 3s/step - loss: 0.3151 - acc: 0.8685 - val_loss: 0.2828 - val_acc: 0.8788
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2775 - acc: 0.9004
# Epoch 21: acc improved from 0.88446 to 0.90040, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 12s 3s/step - loss: 0.2775 - acc: 0.9004 - val_loss: 0.2794 - val_acc: 0.8788
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2708 - acc: 0.9203
# Epoch 22: acc improved from 0.90040 to 0.92032, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 12s 3s/step - loss: 0.2708 - acc: 0.9203 - val_loss: 0.2520 - val_acc: 0.9394
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2655 - acc: 0.9203
# Epoch 23: acc did not improve from 0.92032
# 4/4 [==============================] - 12s 3s/step - loss: 0.2655 - acc: 0.9203 - val_loss: 0.2501 - val_acc: 0.9242
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2248 - acc: 0.9363
# Epoch 24: acc improved from 0.92032 to 0.93625, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.2248 - acc: 0.9363 - val_loss: 0.2457 - val_acc: 0.8939
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2714 - acc: 0.9004
# Epoch 25: acc did not improve from 0.93625
# 4/4 [==============================] - 13s 3s/step - loss: 0.2714 - acc: 0.9004 - val_loss: 0.2242 - val_acc: 0.9394
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2396 - acc: 0.9163
# Epoch 26: acc did not improve from 0.93625
# 4/4 [==============================] - 13s 3s/step - loss: 0.2396 - acc: 0.9163 - val_loss: 0.2140 - val_acc: 0.9545
# Epoch 27/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2409 - acc: 0.9323
# Epoch 27: acc did not improve from 0.93625
# 4/4 [==============================] - 13s 3s/step - loss: 0.2409 - acc: 0.9323 - val_loss: 0.2932 - val_acc: 0.8636
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1846 - acc: 0.9602
# Epoch 28: acc improved from 0.93625 to 0.96016, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.1846 - acc: 0.9602 - val_loss: 0.2026 - val_acc: 0.9394
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1882 - acc: 0.9442
# Epoch 29: acc did not improve from 0.96016
# 4/4 [==============================] - 13s 3s/step - loss: 0.1882 - acc: 0.9442 - val_loss: 0.1953 - val_acc: 0.9394
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2018 - acc: 0.9402
# Epoch 30: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.2018 - acc: 0.9402 - val_loss: 0.2348 - val_acc: 0.8636
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1915 - acc: 0.9363
# Epoch 31: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1915 - acc: 0.9363 - val_loss: 0.2281 - val_acc: 0.8636
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2006 - acc: 0.9283
# Epoch 32: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.2006 - acc: 0.9283 - val_loss: 0.1787 - val_acc: 0.9545
# Epoch 33/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1931 - acc: 0.9363
# Epoch 33: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1931 - acc: 0.9363 - val_loss: 0.2011 - val_acc: 0.9242
# Epoch 34/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1808 - acc: 0.9323
# Epoch 34: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1808 - acc: 0.9323 - val_loss: 0.2115 - val_acc: 0.9091
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1923 - acc: 0.9203
# Epoch 35: acc did not improve from 0.96016
# 4/4 [==============================] - 13s 3s/step - loss: 0.1923 - acc: 0.9203 - val_loss: 0.1830 - val_acc: 0.9545
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1796 - acc: 0.9402
# Epoch 36: acc did not improve from 0.96016
# 4/4 [==============================] - 13s 3s/step - loss: 0.1796 - acc: 0.9402 - val_loss: 0.1709 - val_acc: 0.9394
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1442 - acc: 0.9522
# Epoch 37: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1442 - acc: 0.9522 - val_loss: 0.1978 - val_acc: 0.9242
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1390 - acc: 0.9562
# Epoch 38: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1390 - acc: 0.9562 - val_loss: 0.2038 - val_acc: 0.9091
# Epoch 39/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1480 - acc: 0.9482
# Epoch 39: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1480 - acc: 0.9482 - val_loss: 0.1714 - val_acc: 0.9545
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1484 - acc: 0.9323
# Epoch 40: acc did not improve from 0.96016
# 4/4 [==============================] - 13s 3s/step - loss: 0.1484 - acc: 0.9323 - val_loss: 0.1722 - val_acc: 0.9394
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1527 - acc: 0.9562
# Epoch 41: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1527 - acc: 0.9562 - val_loss: 0.1634 - val_acc: 0.9545
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1302 - acc: 0.9442
# Epoch 42: acc did not improve from 0.96016
# 4/4 [==============================] - 12s 3s/step - loss: 0.1302 - acc: 0.9442 - val_loss: 0.1990 - val_acc: 0.9091
# Epoch 43/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1470 - acc: 0.9522
# Epoch 43: acc did not improve from 0.96016
# 4/4 [==============================] - 13s 3s/step - loss: 0.1470 - acc: 0.9522 - val_loss: 0.1652 - val_acc: 0.9394
# Epoch 44/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1238 - acc: 0.9681
# Epoch 44: acc improved from 0.96016 to 0.96813, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 13s 3s/step - loss: 0.1238 - acc: 0.9681 - val_loss: 0.1794 - val_acc: 0.9394
# Epoch 45/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1361 - acc: 0.9602
# Epoch 45: acc did not improve from 0.96813
# 4/4 [==============================] - 13s 3s/step - loss: 0.1361 - acc: 0.9602 - val_loss: 0.1626 - val_acc: 0.9394
# Epoch 46/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1225 - acc: 0.9602
# Epoch 46: acc did not improve from 0.96813
# 4/4 [==============================] - 12s 3s/step - loss: 0.1225 - acc: 0.9602 - val_loss: 0.1541 - val_acc: 0.9697
# Epoch 47/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1112 - acc: 0.9681
# Epoch 47: acc did not improve from 0.96813
# 4/4 [==============================] - 12s 3s/step - loss: 0.1112 - acc: 0.9681 - val_loss: 0.1699 - val_acc: 0.9394
# Epoch 48/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1166 - acc: 0.9482
# Epoch 48: acc did not improve from 0.96813
# 4/4 [==============================] - 12s 3s/step - loss: 0.1166 - acc: 0.9482 - val_loss: 0.1574 - val_acc: 0.9394
# Epoch 49/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0958 - acc: 0.9562
# Epoch 49: acc did not improve from 0.96813
# 4/4 [==============================] - 12s 3s/step - loss: 0.0958 - acc: 0.9562 - val_loss: 0.1689 - val_acc: 0.9394
# Epoch 50/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1149 - acc: 0.9442
# Epoch 50: acc did not improve from 0.96813
# 4/4 [==============================] - 12s 3s/step - loss: 0.1149 - acc: 0.9442 - val_loss: 0.1943 - val_acc: 0.9242

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.legend();
    plt.figure();

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.legend();

plot_learning_curve(history)

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

no_augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
no_augmented_df
# Out:
# 4/4 [==============================] - 10s 2s/step - loss: 0.0619 - acc: 0.9801
# 2/2 [==============================] - 2s 29ms/step - loss: 0.1943 - acc: 0.9242
#          Train       Val
# Loss  0.061917  0.194338
# Acc   0.980080  0.924242

# %%
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))
# Out:
# 3/3 [==============================] - 3s 68ms/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86        20
#          1.0       0.80      1.00      0.89        20
#          2.0       1.00      1.00      1.00        26
#
#     accuracy                           0.92        66
#    macro avg       0.93      0.92      0.92        66
# weighted avg       0.94      0.92      0.92        66
